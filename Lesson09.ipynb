# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("olympics.csv", skiprows=4)

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
df.describe()
# Out:
#             Edition
# count  29216.000000
# mean    1967.713171
# std       32.406293
# min     1896.000000
# 25%     1948.000000
# 50%     1976.000000
# 75%     1996.000000
# max     2008.000000

# %%
df1 = pd.read_csv('FuelConsumptionCo2.csv')

# %%
df1.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
df1.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
df.describe()
# Out:
#             Edition
# count  29216.000000
# mean    1967.713171
# std       32.406293
# min     1896.000000
# 25%     1948.000000
# 50%     1976.000000
# 75%     1996.000000
# max     2008.000000

# %%
rec = df[(df.Edition > 2000) & (df.Medal=='Gold')]

# %%
rec.NOC.value_counts().head(1)
# Out:
# USA    241
# Name: NOC, dtype: int64

# %%
rec.NOC.value_counts(ascending=True).tail(1)
# Out:
# USA    241
# Name: NOC, dtype: int64

# %%
df[df.Edition==1896].Sport.value_counts().plot()

# %%
df[df.Edition==1896].Sport.value_counts().plot(kind='bar');

# %%
df[df.Edition==1896].Sport.value_counts().plot(kind='barh');

# %%
df[df.Edition==1896].Sport.value_counts().plot(kind='pie');

# %%
res = df[df.Edition==1896].Sport.value_counts()

# %%
res.plot(kind='bar', colormap='Pastel1' )

# %%
res.plot(kind='bar', figsize=(3, 2) );

# %%
res.head()
# Out:
# Gymnastics    45
# Athletics     37
# Cycling       16
# Shooting      15
# Aquatics      11
# Name: Sport, dtype: int64

# %%
res.sum()
# Out:
# 151

# %%
df[df.NOC=='CHN'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 679 entries, 16592 to 29204
# Data columns (total 10 columns):
# City            679 non-null object
# Edition         679 non-null int64
# Sport           679 non-null object
# Discipline      679 non-null object
# Athlete         679 non-null object
# NOC             679 non-null object
# Gender          679 non-null object
# Event           679 non-null object
# Event_gender    679 non-null object
# Medal           679 non-null object
# dtypes: int64(1), object(9)
# memory usage: 58.4+ KB

# %%
df[(df.NOC=='CHN')].Edition.value_counts()
# Out:
# 2008    184
# 1996    110
# 2004     94
# 1992     83
# 2000     79
# 1984     76
# 1988     53
# Name: Edition, dtype: int64

# %%
df[(df.NOC=='CHN') & (df.Edition > 2000)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 278 entries, 25176 to 29204
# Data columns (total 10 columns):
# City            278 non-null object
# Edition         278 non-null int64
# Sport           278 non-null object
# Discipline      278 non-null object
# Athlete         278 non-null object
# NOC             278 non-null object
# Gender          278 non-null object
# Event           278 non-null object
# Event_gender    278 non-null object
# Medal           278 non-null object
# dtypes: int64(1), object(9)
# memory usage: 23.9+ KB

# %%
df[(df.NOC=='CHN')].Edition.value_counts()
# Out:
# 2008    184
# 1996    110
# 2004     94
# 1992     83
# 2000     79
# 1984     76
# 1988     53
# Name: Edition, dtype: int64

# %%
import seaborn as sns

# %%
mw = df[(df.Edition==2008) & (df.NOC=='CHN')]
mw = mw.Gender.value_counts()

# %%
mw.plot(kind="bar", figsize=(3,2));

# %%
mwsea = df[(df.Edition==2008) & (df.NOC=='CHN')]

# %%
sns.countplot(data=mwsea, x='Gender');

# %%
sns.countplot(data=mwsea, x='Medal', hue="Gender");

# %%
sns.countplot(data=mwsea, x='Medal', hue="Gender", order=['Gold', 'Silver', 'Bronze'] );

# %%
df1
# Out:
#       MODELYEAR          MAKE                        MODEL    VEHICLECLASS  \
# 0          2014         ACURA                          ILX         COMPACT
# 1          2014         ACURA                          ILX         COMPACT
# 2          2014         ACURA                   ILX HYBRID         COMPACT
# 3          2014         ACURA                      MDX 4WD     SUV - SMALL
# 4          2014         ACURA                      RDX AWD     SUV - SMALL
# 5          2014         ACURA                          RLX        MID-SIZE
# 6          2014         ACURA                           TL        MID-SIZE
# 7          2014         ACURA                       TL AWD        MID-SIZE
# 8          2014         ACURA                       TL AWD        MID-SIZE
# 9          2014         ACURA                          TSX         COMPACT
# 10         2014         ACURA                          TSX         COMPACT
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
# MODELYEAR                   1067 non-null int64
# MAKE                        1067 non-null object
# MODEL                       1067 non-null object
# VEHICLECLASS                1067 non-null object
# ENGINESIZE                  1067 non-null float64
# CYLINDERS                   1067 non-null int64
# TRANSMISSION                1067 non-null object
# FUELTYPE                    1067 non-null object
# FUELCONSUMPTION_CITY        1067 non-null float64
# FUELCONSUMPTION_HWY         1067 non-null float64
# FUELCONSUMPTION_COMB        1067 non-null float64
# FUELCONSUMPTION_COMB_MPG    1067 non-null int64
# CO2EMISSIONS                1067 non-null int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 108.4+ KB
