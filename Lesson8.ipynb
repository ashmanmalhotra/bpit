# %%
import pandas as pd

# %%
df = pd.read_csv('olympics.csv', skiprows=4)

# %%
df.head(10)
# Out:
#      City  Edition     Sport Discipline                Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming       HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming      DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming     MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming     CHASAPIS, Spiridon  GRE    Men
# 5  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 6  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 7  Athens     1896  Aquatics   Swimming       ANDREOU, Joannis  GRE    Men
# 8  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 9  Athens     1896  Aquatics   Swimming          NEUMANN, Paul  AUT    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.City)
# Out:
# pandas.core.series.Series

# %%
df.City.head(10)
# Out:
# 0    Athens
# 1    Athens
# 2    Athens
# 3    Athens
# 4    Athens
# 5    Athens
# 6    Athens
# 7    Athens
# 8    Athens
# 9    Athens
# Name: City, dtype: object

# %%
df['City'].head()
# Out:
# 0    Athens
# 1    Athens
# 2    Athens
# 3    Athens
# 4    Athens
# Name: City, dtype: object

# %%
df.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender',
#        'Event', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
df1 = df[['City', 'Edition', 'Sport']].head()

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1
# Out:
#      City  Edition     Sport
# 0  Athens     1896  Aquatics
# 1  Athens     1896  Aquatics
# 2  Athens     1896  Aquatics
# 3  Athens     1896  Aquatics
# 4  Athens     1896  Aquatics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df.Medal.value_counts()
# Out:
# Gold      9850
# Bronze    9689
# Silver    9677
# Name: Medal, dtype: int64

# %%
df.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
df.Event_gender.value_counts(ascending=True)
# Out:
# X     1871
# W     7278
# M    20067
# Name: Event_gender, dtype: int64

# %%
df.Edition.sort_values(ascending=False)
# Out:
# 29215    2008
# 27858    2008
# 27845    2008
# 27846    2008
# 27847    2008
# 27848    2008
# 27849    2008
# 27850    2008
# 27851    2008
# 27852    2008
# 27853    2008
# 27854    2008
# 27855    2008
# 27856    2008
# 27857    2008
# 27859    2008
# 27843    2008
# 27860    2008
# 27861    2008
# 27862    2008
# 27863    2008
# 27864    2008
# 27865    2008
# 27866    2008
# 27867    2008
# 27868    2008
# 27869    2008
# 27870    2008
# 27871    2008
# 27872    2008
#          ...
# 87       1896
# 86       1896
# 85       1896
# 84       1896
# 83       1896
# 82       1896
# 81       1896
# 80       1896
# 79       1896
# 78       1896
# 93       1896
# 95       1896
# 112      1896
# 96       1896
# 111      1896
# 110      1896
# 109      1896
# 108      1896
# 107      1896
# 106      1896
# 105      1896
# 104      1896
# 103      1896
# 102      1896
# 101      1896
# 100      1896
# 99       1896
# 98       1896
# 97       1896
# 0        1896
# ...

# %%
df.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender',
#        'Event', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
df2 = df.copy()

# %%
df3 = df2.sort_values(by=['Sport', 'Discipline'])

# %%
df2.head()
# Out:
#          City  Edition     Sport Discipline                 Athlete  NOC  \
# 663  St Louis     1904  Aquatics     Diving  BRAUNSCHWEIGER, Alfred  GER
# 664  St Louis     1904  Aquatics     Diving            KEHOE, Frank  USA
# 665  St Louis     1904  Aquatics     Diving         SHELDON, George  USA
# 666  St Louis     1904  Aquatics     Diving         HOFFMANN, Georg  GER
# 667  St Louis     1904  Aquatics     Diving       GOODWIN, Leo Budd  USA
#
#     Gender                Event Event_gender   Medal
# 663    Men         10m platform            M  Bronze
# 664    Men         10m platform            M  Bronze
# 665    Men         10m platform            M    Gold
# 666    Men         10m platform            M  Silver
# 667    Men  plunge for distance            M  Bronze

# %% [markdown]
# # Boolean Indexing

# %%
df[df.Medal == 'Gold']
# Out:
#           City  Edition          Sport       Discipline  \
# 0       Athens     1896       Aquatics         Swimming
# 3       Athens     1896       Aquatics         Swimming
# 6       Athens     1896       Aquatics         Swimming
# 9       Athens     1896       Aquatics         Swimming
# 13      Athens     1896      Athletics        Athletics
# 15      Athens     1896      Athletics        Athletics
# 18      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 24      Athens     1896      Athletics        Athletics
# 27      Athens     1896      Athletics        Athletics
# 29      Athens     1896      Athletics        Athletics
# 33      Athens     1896      Athletics        Athletics
# 36      Athens     1896      Athletics        Athletics
# 40      Athens     1896      Athletics        Athletics
# 43      Athens     1896      Athletics        Athletics
# 46      Athens     1896      Athletics        Athletics
# ...

# %%
df[(df.Medal == 'Gold') & (df.Discipline == 'Swimming')]
# Out:
#            City  Edition     Sport Discipline                   Athlete  NOC  \
# 0        Athens     1896  Aquatics   Swimming             HAJOS, Alfred  HUN
# 3        Athens     1896  Aquatics   Swimming        MALOKINIS, Ioannis  GRE
# 6        Athens     1896  Aquatics   Swimming             HAJOS, Alfred  HUN
# 9        Athens     1896  Aquatics   Swimming             NEUMANN, Paul  AUT
# 152       Paris     1900  Aquatics   Swimming       JARVIS, John Arthur  GBR
# 155       Paris     1900  Aquatics   Swimming         HOPPENBERG, Ernst  GER
# 158       Paris     1900  Aquatics   Swimming      LANE, Frederick C.V.  AUS
# 161       Paris     1900  Aquatics   Swimming      LANE, Frederick C.V.  AUS
# 168       Paris     1900  Aquatics   Swimming              FREY, Julius  GER
# 169       Paris     1900  Aquatics   Swimming               HAINLE, Max  GER
# 170       Paris     1900  Aquatics   Swimming         HOPPENBERG, Ernst  GER
# ...

# %%
df.
